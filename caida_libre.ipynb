# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 10, 100)
y = 9.8 * t**2 / 2  # Caída libre

plt.plot(t, y)
plt.xlabel('Tiempo (s)')
plt.ylabel('Distancia (m)')
plt.title('Caída libre')
plt.grid()
plt.show()
